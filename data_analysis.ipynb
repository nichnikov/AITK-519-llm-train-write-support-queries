# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_feather(os.path.join(os.getcwd(), "data_light", "queries_2020_0.feather"))
df["QueryLen"] = df["QueryText"].apply(lambda x: len(str(x).split()))
df["AnswerLen"] = df["Answer"].apply(lambda x: len(str(x).split()))
df
# Out:
#        QueryNumber  QueryPart      QueryCreateDate  Sys     Pub  \
# 0          2574694          0  2021-06-10 21:15:43  БСС  БСС КУ
# 1          2386544          0  2021-02-24 11:50:51  БСС  БСС КУ
# 2          2389092          0  2021-02-25 12:12:08  БСС  БСС КУ
# 3          2397704          0  2021-03-02 14:47:39  БСС  БСС КУ
# 4          2026880          0  2020-03-25 14:59:09  БСС  БСС КУ
# ...            ...        ...                  ...  ...     ...
# 19995      2018477          0  2020-03-17 17:39:54  БСС  БСС КУ
# 19996      2018509          0  2020-03-17 18:05:11  БСС  БСС КУ
# 19997      2022520          0  2020-03-20 16:38:45  БСС  БСС КУ
# 19998      2022556          0  2020-03-20 17:00:19  БСС  БСС КУ
# 19999      2024181          0  2020-03-23 17:37:38  БСС  БСС КУ
#
#                     UserLogin      ExpertLogin              ExpertName  \
# 0            _dewolf_@mail.ru  tatyana-garnaga              Маслова Т.
# 1            _sveta68@mail.ru       expert0005            Ермаченко А.
# 2            _sveta68@mail.ru       expert0005            Ермаченко А.
# 3      +79063274140@yandex.ru          janie_a        Мещирякова Е. И.
# 4          0_vavilina@mail.ru      mikushina_g  Микушина (Лобурец ) Г.
# ...                       ...              ...                     ...
# 19995    buh2017dok@gmail.com      gabsalamova       Габсалямова Л. Н.
# 19996    buh2017dok@gmail.com      gabsalamova       Габсалямова Л. Н.
# 19997    buh2017dok@gmail.com        romasanna            Юрова  А. С.
# 19998    buh2017dok@gmail.com        expert398               Жукова М.
# 19999    buh2017dok@gmail.com        expert398               Жукова М.
#
#                                                QueryText  \
# 0      Здравствуйте, вопрос такой, в налоговой зареги...
# 1      Доброе утро! Собственник моей компании имеет н...
# 2      Интересует нюансы работы в управляющей компани...
# 3      добрый день,вопрос\nнаша организация занимаетс...
# 4      Добрый день.Не подскажите,если у нас есть поме...
# ...                                                  ...
# 19995  Организация перевела валютные средства с валют...
# 19996  организация разместила валютные средства на де...
# 19997  Добрый день! Продавец (на ОСНО) 09.12.2020г  в...
# 19998  Добрый день! Директор организации для расчета ...
# 19999  Добрый день! Организация приобрела подарки к 8...
#
#                                                   Answer  \
# 0      Нет, не откажут. Можно уведомить налоговую о н...
# 1      Положительные или отрицательные моменты по упр...
# 2      В рамках данного запроса в ответе может быть р...
# 3      Право на вычет по приобретенным услугам возник...
# 4      По вопросу налогообложения доходов от продажи ...
# ...                                                  ...
# 19995  Бухучет&nbsp;валютных&nbsp;операций&nbsp;ведет...
# 19996  В бухучете размещение и возврат средств по деп...
# 19997  Из текста вопроса следует, что покупатель опла...
# 19998  В день, когда сотрудник (директор) должен был ...
# 19999  Компенсацию сотруднику затрат и входной НДС сп...
#
#                                               AnswerType      heading  \
# 0      Нет ответа в Системе, вопрос общий, рекомендуе...  Юридические
# 1                                   Есть ответ в Системе  Особенности
# 2                                   Есть ответ в Системе  Особенности
# 3      Нет ответа в Системе, вопрос ситуативный (част...       Налоги
# 4                                   Есть ответ в Системе       Налоги
# ...                                                  ...          ...
# 19995                               Есть ответ в Системе         Учет
# 19996                               Есть ответ в Системе         Учет
# 19997                               Есть ответ в Системе      Расчеты
# 19998                               Есть ответ в Системе   Сотрудники
# 19999                               Есть ответ в Системе   Сотрудники
#
#                                             ChildHeading  QueryLen  AnswerLen
# 0                                    Хозяйственные споры        69         64
# 1      Совместная деятельность, простое товарищество,...        39        304
# 2      Совместная деятельность, простое товарищество,...        48        518
# 3                                                    НДС        34        184
# 4                                                    УСН        62        243
# ...                                                  ...       ...        ...
# 19995                                           Проводки        30        233
# 19996                                           Проводки        28        158
# 19997                                             Валюта        49        245
# 19998                                       Подотчётники        51        367
# 19999                                       Подотчётники        50        228
#
# [20000 rows x 15 columns]

# %%
df[["QueryLen"]][:100]
# Out:
#     QueryLen
# 0         69
# 1         39
# 2         48
# 3         34
# 4         62
# ..       ...
# 95        10
# 96        42
# 97        32
# 98        28
# 99        22
#
# [100 rows x 1 columns]

# %%
# df[["QueryLen"]][:100].plot.bar(rot=0)
df[["QueryLen"]].plot.hist(bins=100)
df[["AnswerLen"]].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
